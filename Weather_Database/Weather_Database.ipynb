# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather['weather'][0]['description']
# Out:
# 'overcast clouds'

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | ushuaia
# Processing Record 2 of Set 16 | asau
# Processing Record 3 of Set 16 | rikitea
# Processing Record 4 of Set 16 | fortuna
# Processing Record 5 of Set 16 | antsohihy
# Processing Record 6 of Set 16 | vaini
# Processing Record 7 of Set 16 | praia da vitoria
# Processing Record 8 of Set 16 | punta arenas
# Processing Record 9 of Set 16 | tuktoyaktuk
# Processing Record 10 of Set 16 | chuy
# Processing Record 11 of Set 16 | sonoita
# Processing Record 12 of Set 16 | chapleau
# Processing Record 13 of Set 16 | bengkulu
# Processing Record 14 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 16 | victoria
# Processing Record 16 of Set 16 | busselton
# Processing Record 17 of Set 16 | torbay
# Processing Record 18 of Set 16 | barrow
# Processing Record 19 of Set 16 | jalu
# Processing Record 20 of Set 16 | albany
# Processing Record 21 of Set 16 | khani
# Processing Record 22 of Set 16 | dikson
# Processing Record 23 of Set 16 | castro
# Processing Record 24 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 16 | cidreira
# Processing Record 26 of Set 16 | manicore
# Processing Record 27 of Set 16 | hobart
# Processing Record 28 of Set 16 | isla mujeres
# Processing Record 29 of Set 16 | bluff
# Processing Record 30 of Set 16 | tilichiki
# Processing Record 31 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 16 | airai
# Processing Record 33 of Set 16 | hurricane
# Processing Record 34 of Set 16 | port hardy
# Processing Record 35 of Set 16 | manggar
# Processing Record 36 of Set 16 | linxia
# Processing Record 37 of Set 16 | arraial do cabo
# Processing Record 38 of Set 16 | lebu
# Processing Record 39 of Set 16 | hilo
# Processing Record 40 of Set 16 | qaanaaq
# Processing Record 41 of Set 16 | bambous virieux
# Processing Record 42 of Set 16 | kapaa
# Processing Record 43 of Set 16 | saint-philippe
# Processing Record 44 of Set 16 | vanavara
# Processing Record 45 of Set 16 | salym
# Processing Record 46 of Set 16 | mogadishu
# Processing Record 47 of Set 16 | vila velha
# Processing Record 48 of Set 16 | manaia
# Processing Record 49 of Set 16 | cape town
# Processing Record 50 of Set 16 | kununurra
# Processing Record 1 of Set 17 | mataura
# Processing Record 2 of Set 17 | port alfred
# Processing Record 3 of Set 17 | khatanga
# Processing Record 4 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 17 | katsuura
# Processing Record 6 of Set 17 | lagoa
# Processing Record 7 of Set 17 | haines junction
# Processing Record 8 of Set 17 | verkhnyaya toyma
# Processing Record 9 of Set 17 | butaritari
# Processing Record 10 of Set 17 | ilulissat
# Processing Record 11 of Set 17 | kamaishi
# Processing Record 12 of Set 17 | jamestown
# Processing Record 13 of Set 17 | staryy nadym
# Processing Record 14 of Set 17 | ambilobe
# Processing Record 15 of Set 17 | faqirwali
# Processing Record 16 of Set 17 | trinidad
# Processing Record 17 of Set 17 | namibe
# Processing Record 18 of Set 17 | mumford
# Processing Record 19 of Set 17 | lukulu
# Processing Record 20 of Set 17 | carnarvon
# Processing Record 21 of Set 17 | kodiak
# Processing Record 22 of Set 17 | sola
# Processing Record 23 of Set 17 | yakeshi
# Processing Record 24 of Set 17 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 17 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 17 | imatra
# Processing Record 27 of Set 17 | byron bay
# Processing Record 28 of Set 17 | east london
# Processing Record 29 of Set 17 | cumaru
# Processing Record 30 of Set 17 | san patricio
# Processing Record 31 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 17 | birao
# Processing Record 33 of Set 17 | boa vista
# Processing Record 34 of Set 17 | viedma
# Processing Record 35 of Set 17 | zeya
# Processing Record 36 of Set 17 | provideniya
# Processing Record 37 of Set 17 | chumikan
# Processing Record 38 of Set 17 | olinda
# Processing Record 39 of Set 17 | karatau
# Processing Record 40 of Set 17 | santa maria
# Processing Record 41 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 17 | vila franca do campo
# Processing Record 43 of Set 17 | deputatskiy
# Processing Record 44 of Set 17 | oropesa
# Processing Record 45 of Set 17 | puno
# Processing Record 46 of Set 17 | yerbogachen
# Processing Record 47 of Set 17 | borogontsy
# Processing Record 48 of Set 17 | college
# Processing Record 49 of Set 17 | kruisfontein
# Processing Record 50 of Set 17 | yucca valley
# Processing Record 1 of Set 18 | tromso
# Processing Record 2 of Set 18 | severo-kurilsk
# Processing Record 3 of Set 18 | hermanus
# Processing Record 4 of Set 18 | puri
# Processing Record 5 of Set 18 | codrington
# Processing Record 6 of Set 18 | sur
# Processing Record 7 of Set 18 | cabo san lucas
# Processing Record 8 of Set 18 | ahipara
# Processing Record 9 of Set 18 | gwadar
# Processing Record 10 of Set 18 | port elizabeth
# Processing Record 11 of Set 18 | floro
# Processing Record 12 of Set 18 | paradwip
# City not found. Skipping...
# Processing Record 13 of Set 18 | cururupu
# Processing Record 14 of Set 18 | atuona
# Processing Record 15 of Set 18 | egvekinot
# Processing Record 16 of Set 18 | rock springs
# Processing Record 17 of Set 18 | hithadhoo
# Processing Record 18 of Set 18 | ancud
# Processing Record 19 of Set 18 | pangnirtung
# Processing Record 20 of Set 18 | arrifes
# Processing Record 21 of Set 18 | high level
# Processing Record 22 of Set 18 | sawtell
# Processing Record 23 of Set 18 | sorland
# Processing Record 24 of Set 18 | esperance
# Processing Record 25 of Set 18 | bethel
# Processing Record 26 of Set 18 | haapiti
# Processing Record 27 of Set 18 | bijie
# Processing Record 28 of Set 18 | burnie
# Processing Record 29 of Set 18 | benghazi
# Processing Record 30 of Set 18 | garissa
# Processing Record 31 of Set 18 | puerto ayora
# Processing Record 32 of Set 18 | lompoc
# Processing Record 33 of Set 18 | kaitangata
# Processing Record 34 of Set 18 | mehamn
# Processing Record 35 of Set 18 | nome
# Processing Record 36 of Set 18 | new norfolk
# Processing Record 37 of Set 18 | takoradi
# Processing Record 38 of Set 18 | acapulco
# Processing Record 39 of Set 18 | kamenka
# Processing Record 40 of Set 18 | thompson
# Processing Record 41 of Set 18 | tura
# Processing Record 42 of Set 18 | cayenne
# Processing Record 43 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 18 | inirida
# Processing Record 45 of Set 18 | grand gaube
# Processing Record 46 of Set 18 | komsomolskiy
# Processing Record 47 of Set 18 | leon
# Processing Record 48 of Set 18 | wanaka
# Processing Record 49 of Set 18 | matay
# Processing Record 50 of Set 18 | kavaratti
# Processing Record 1 of Set 19 | mar del plata
# Processing Record 2 of Set 19 | gat
# Processing Record 3 of Set 19 | portland
# Processing Record 4 of Set 19 | vardo
# Processing Record 5 of Set 19 | chokurdakh
# Processing Record 6 of Set 19 | kuching
# Processing Record 7 of Set 19 | taoudenni
# Processing Record 8 of Set 19 | cherskiy
# Processing Record 9 of Set 19 | puerto escondido
# Processing Record 10 of Set 19 | bredasdorp
# Processing Record 11 of Set 19 | mount pleasant
# Processing Record 12 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 19 | senanga
# Processing Record 14 of Set 19 | faanui
# Processing Record 15 of Set 19 | tasiilaq
# Processing Record 16 of Set 19 | hamilton
# Processing Record 17 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 19 | emerald
# Processing Record 19 of Set 19 | hofn
# Processing Record 20 of Set 19 | korla
# Processing Record 21 of Set 19 | porto novo
# Processing Record 22 of Set 19 | xingtai
# Processing Record 23 of Set 19 | boddam
# Processing Record 24 of Set 19 | havelock
# Processing Record 25 of Set 19 | pevek
# Processing Record 26 of Set 19 | hanzhong
# Processing Record 27 of Set 19 | northam
# Processing Record 28 of Set 19 | mana
# Processing Record 29 of Set 19 | abha
# Processing Record 30 of Set 19 | ribnica
# Processing Record 31 of Set 19 | krasnoarmeysk
# Processing Record 32 of Set 19 | talnakh
# Processing Record 33 of Set 19 | heihe
# Processing Record 34 of Set 19 | rundu
# Processing Record 35 of Set 19 | husavik
# Processing Record 36 of Set 19 | lasa
# Processing Record 37 of Set 19 | isangel
# Processing Record 38 of Set 19 | nizhneivkino
# Processing Record 39 of Set 19 | roald
# Processing Record 40 of Set 19 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 19 | chikoy
# City not found. Skipping...
# Processing Record 42 of Set 19 | saint-fons
# Processing Record 43 of Set 19 | uaua
# Processing Record 44 of Set 19 | yellowknife
# Processing Record 45 of Set 19 | kendari
# Processing Record 46 of Set 19 | amga
# Processing Record 47 of Set 19 | palomares
# Processing Record 48 of Set 19 | yelan-koleno
# Processing Record 49 of Set 19 | kavieng
# Processing Record 50 of Set 19 | beringovskiy
# Processing Record 1 of Set 20 | huarmey
# Processing Record 2 of Set 20 | vanimo
# Processing Record 3 of Set 20 | usinsk
# Processing Record 4 of Set 20 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 20 | mutis
# Processing Record 6 of Set 20 | vikhorevka
# Processing Record 7 of Set 20 | quelimane
# Processing Record 8 of Set 20 | lorengau
# Processing Record 9 of Set 20 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 20 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 20 | tikamgarh
# Processing Record 12 of Set 20 | upernavik
# Processing Record 13 of Set 20 | vilyuysk
# Processing Record 14 of Set 20 | izhma
# Processing Record 15 of Set 20 | chernyshevskiy
# Processing Record 16 of Set 20 | mount isa
# Processing Record 17 of Set 20 | sovetskiy
# Processing Record 18 of Set 20 | berlevag
# Processing Record 19 of Set 20 | kuryk
# Processing Record 20 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 20 | state college
# Processing Record 22 of Set 20 | leningradskiy
# Processing Record 23 of Set 20 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 20 | luwuk
# Processing Record 25 of Set 20 | auki
# Processing Record 26 of Set 20 | guelengdeng
# City not found. Skipping...
# Processing Record 27 of Set 20 | aklavik
# Processing Record 28 of Set 20 | cooma
# Processing Record 29 of Set 20 | sol-iletsk
# Processing Record 30 of Set 20 | kijabe
# Processing Record 31 of Set 20 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 20 | vostok
# Processing Record 33 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 20 | teguise
# Processing Record 35 of Set 20 | mahebourg
# Processing Record 36 of Set 20 | vao
# Processing Record 37 of Set 20 | neiafu
# Processing Record 38 of Set 20 | bulawayo
# Processing Record 39 of Set 20 | mattru
# Processing Record 40 of Set 20 | merauke
# Processing Record 41 of Set 20 | nurota
# Processing Record 42 of Set 20 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 20 | georgetown
# Processing Record 44 of Set 20 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 20 | tiksi
# Processing Record 46 of Set 20 | badaojiang
# City not found. Skipping...
# Processing Record 47 of Set 20 | broken hill
# Processing Record 48 of Set 20 | sinnar
# Processing Record 49 of Set 20 | fairbanks
# Processing Record 50 of Set 20 | hue
# Processing Record 1 of Set 21 | esmeraldas
# Processing Record 2 of Set 21 | cheremukhovo
# Processing Record 3 of Set 21 | tuatapere
# Processing Record 4 of Set 21 | khuzhir
# Processing Record 5 of Set 21 | faya
# Processing Record 6 of Set 21 | te anau
# Processing Record 7 of Set 21 | nikolskoye
# Processing Record 8 of Set 21 | mutum
# Processing Record 9 of Set 21 | shimanovsk
# Processing Record 10 of Set 21 | ponta do sol
# Processing Record 11 of Set 21 | alyangula
# Processing Record 12 of Set 21 | ekibastuz
# Processing Record 13 of Set 21 | sitka
# Processing Record 14 of Set 21 | huescar
# Processing Record 15 of Set 21 | marawi
# Processing Record 16 of Set 21 | alta floresta
# Processing Record 17 of Set 21 | cam ranh
# Processing Record 18 of Set 21 | saint-leu
# Processing Record 19 of Set 21 | nemuro
# Processing Record 20 of Set 21 | krasnovishersk
# Processing Record 21 of Set 21 | souillac
# Processing Record 22 of Set 21 | riohacha
# Processing Record 23 of Set 21 | coquimbo
# Processing Record 24 of Set 21 | clyde river
# Processing Record 25 of Set 21 | bababe
# City not found. Skipping...
# Processing Record 26 of Set 21 | ewo
# Processing Record 27 of Set 21 | fort nelson
# Processing Record 28 of Set 21 | bairnsdale
# Processing Record 29 of Set 21 | awbari
# Processing Record 30 of Set 21 | aktas
# Processing Record 31 of Set 21 | saskylakh
# Processing Record 32 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 21 | sawakin
# Processing Record 34 of Set 21 | beidao
# Processing Record 35 of Set 21 | waipawa
# Processing Record 36 of Set 21 | placido de castro
# Processing Record 37 of Set 21 | tula
# Processing Record 38 of Set 21 | barraute
# Processing Record 39 of Set 21 | schmallenberg
# Processing Record 40 of Set 21 | volchikha
# Processing Record 41 of Set 21 | miraflores
# Processing Record 42 of Set 21 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 21 | itarema
# Processing Record 44 of Set 21 | tieli
# Processing Record 45 of Set 21 | yenisehir
# Processing Record 46 of Set 21 | yulara
# Processing Record 47 of Set 21 | nanortalik
# Processing Record 48 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 21 | bracciano
# Processing Record 50 of Set 21 | crixas
# Processing Record 1 of Set 22 | rudbar
# Processing Record 2 of Set 22 | voznesenye
# Processing Record 3 of Set 22 | hasaki
# Processing Record 4 of Set 22 | maningrida
# Processing Record 5 of Set 22 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 22 | teahupoo
# Processing Record 7 of Set 22 | havre-saint-pierre
# Processing Record 8 of Set 22 | ribeira grande
# Processing Record 9 of Set 22 | labuhan
# Processing Record 10 of Set 22 | palmer
# Processing Record 11 of Set 22 | sabha
# Processing Record 12 of Set 22 | ottawa
# Processing Record 13 of Set 22 | kabinda
# Processing Record 14 of Set 22 | kahului
# Processing Record 15 of Set 22 | luderitz
# Processing Record 16 of Set 22 | tanout
# Processing Record 17 of Set 22 | longyearbyen
# Processing Record 18 of Set 22 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 22 | misratah
# Processing Record 20 of Set 22 | umm lajj
# Processing Record 21 of Set 22 | posse
# Processing Record 22 of Set 22 | saint-francois
# Processing Record 23 of Set 22 | homer
# Processing Record 24 of Set 22 | boende
# Processing Record 25 of Set 22 | chapais
# Processing Record 26 of Set 22 | saint-joseph
# Processing Record 27 of Set 22 | jaffna
# Processing Record 28 of Set 22 | makakilo city
# Processing Record 29 of Set 22 | mulanje
# Processing Record 30 of Set 22 | sibu
# Processing Record 31 of Set 22 | santa rosa
# Processing Record 32 of Set 22 | buri
# Processing Record 33 of Set 22 | pavlovskiy
# Processing Record 34 of Set 22 | yinchuan
# Processing Record 35 of Set 22 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 22 | vila
# Processing Record 37 of Set 22 | kwekwe
# Processing Record 38 of Set 22 | eureka
# Processing Record 39 of Set 22 | karema
# Processing Record 40 of Set 22 | talgar
# Processing Record 41 of Set 22 | keetmanshoop
# Processing Record 42 of Set 22 | laguna
# Processing Record 43 of Set 22 | bubaque
# Processing Record 44 of Set 22 | uray
# Processing Record 45 of Set 22 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 22 | shevchenko
# Processing Record 47 of Set 22 | bria
# Processing Record 48 of Set 22 | yeppoon
# Processing Record 49 of Set 22 | maumere
# Processing Record 50 of Set 22 | flinders
# Processing Record 1 of Set 23 | norman wells
# Processing Record 2 of Set 23 | beloha
# Processing Record 3 of Set 23 | rockport
# Processing Record 4 of Set 23 | waynesville
# Processing Record 5 of Set 23 | beira
# Processing Record 6 of Set 23 | riachao do jacuipe
# Processing Record 7 of Set 23 | karlskoga
# Processing Record 8 of Set 23 | crestview
# Processing Record 9 of Set 23 | zaraza
# Processing Record 10 of Set 23 | abu zabad
# Processing Record 11 of Set 23 | micheweni
# Processing Record 12 of Set 23 | saldanha
# Processing Record 13 of Set 23 | prince rupert
# Processing Record 14 of Set 23 | inhambane
# Processing Record 15 of Set 23 | kigoma
# Processing Record 16 of Set 23 | nam tha
# City not found. Skipping...
# Processing Record 17 of Set 23 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 23 | tongliao
# Processing Record 19 of Set 23 | kirakira
# Processing Record 20 of Set 23 | novi ligure
# Processing Record 21 of Set 23 | chaykovskiy
# Processing Record 22 of Set 23 | kasempa
# Processing Record 23 of Set 23 | isoka
# Processing Record 24 of Set 23 | porto velho
# Processing Record 25 of Set 23 | piryion
# City not found. Skipping...
# Processing Record 26 of Set 23 | grafton
# Processing Record 27 of Set 23 | ostrovnoy
# Processing Record 28 of Set 23 | miandrivazo
# Processing Record 29 of Set 23 | agadez
# Processing Record 30 of Set 23 | andreapol
# Processing Record 31 of Set 23 | vestmannaeyjar
# Processing Record 32 of Set 23 | lavrentiya
# Processing Record 33 of Set 23 | brokopondo
# Processing Record 34 of Set 23 | sergeyevka
# Processing Record 35 of Set 23 | kuusamo
# Processing Record 36 of Set 23 | carutapera
# Processing Record 37 of Set 23 | dzhebariki-khaya
# Processing Record 38 of Set 23 | plyussa
# Processing Record 39 of Set 23 | luganville
# Processing Record 40 of Set 23 | saint pete beach
# Processing Record 41 of Set 23 | ukiah
# Processing Record 42 of Set 23 | cap malheureux
# Processing Record 43 of Set 23 | mikumi
# Processing Record 44 of Set 23 | richards bay
# Processing Record 45 of Set 23 | poronaysk
# Processing Record 46 of Set 23 | tabou
# Processing Record 47 of Set 23 | prieska
# Processing Record 48 of Set 23 | caravelas
# Processing Record 49 of Set 23 | iqaluit
# Processing Record 50 of Set 23 | kitgum
# Processing Record 1 of Set 24 | hambantota
# Processing Record 2 of Set 24 | tuni
# Processing Record 3 of Set 24 | venado tuerto
# Processing Record 4 of Set 24 | avarua
# Processing Record 5 of Set 24 | fukuma
# Processing Record 6 of Set 24 | kirkwall
# Processing Record 7 of Set 24 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 24 | muros
# Processing Record 9 of Set 24 | griffith
# Processing Record 10 of Set 24 | east wenatchee bench
# Processing Record 11 of Set 24 | mackay
# Processing Record 12 of Set 24 | qaqortoq
# Processing Record 13 of Set 24 | pemba
# Processing Record 14 of Set 24 | comodoro rivadavia
# Processing Record 15 of Set 24 | key west
# Processing Record 16 of Set 24 | paracatu
# Processing Record 17 of Set 24 | sioux lookout
# Processing Record 18 of Set 24 | sorong
# Processing Record 19 of Set 24 | moses lake
# Processing Record 20 of Set 24 | soyo
# Processing Record 21 of Set 24 | guilin
# Processing Record 22 of Set 24 | big rapids
# Processing Record 23 of Set 24 | seydi
# Processing Record 24 of Set 24 | masvingo
# Processing Record 25 of Set 24 | ciras
# City not found. Skipping...
# Processing Record 26 of Set 24 | geraldton
# Processing Record 27 of Set 24 | atar
# Processing Record 28 of Set 24 | herat
# Processing Record 29 of Set 24 | trincomalee
# Processing Record 30 of Set 24 | saint george
# Processing Record 31 of Set 24 | narsaq
# Processing Record 32 of Set 24 | olginskaya
# Processing Record 33 of Set 24 | tabuk
# Processing Record 34 of Set 24 | savinka
# Processing Record 35 of Set 24 | sarai
# Processing Record 36 of Set 24 | qui nhon
# Processing Record 37 of Set 24 | palasa
# Processing Record 38 of Set 24 | tapaua
# City not found. Skipping...
# Processing Record 39 of Set 24 | monte alegre
# Processing Record 40 of Set 24 | tevaitoa
# Processing Record 41 of Set 24 | puerto del rosario
# Processing Record 42 of Set 24 | sayansk
# Processing Record 43 of Set 24 | constitucion
# Processing Record 44 of Set 24 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 24 | bahia de caraquez
# Processing Record 46 of Set 24 | shimoda
# Processing Record 47 of Set 24 | salalah
# Processing Record 48 of Set 24 | bonfim
# Processing Record 49 of Set 24 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 24 | baghdad
# Processing Record 1 of Set 25 | kiruna
# Processing Record 2 of Set 25 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 25 | lensk
# Processing Record 4 of Set 25 | mbini
# Processing Record 5 of Set 25 | vilhena
# Processing Record 6 of Set 25 | stornoway
# Processing Record 7 of Set 25 | coihaique
# Processing Record 8 of Set 25 | vylkove
# Processing Record 9 of Set 25 | utiroa
# City not found. Skipping...
# Processing Record 10 of Set 25 | antalaha
# Processing Record 11 of Set 25 | savalou
# Processing Record 12 of Set 25 | irbil
# Processing Record 13 of Set 25 | leshukonskoye
# Processing Record 14 of Set 25 | oeiras
# Processing Record 15 of Set 25 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 25 | nazare
# Processing Record 17 of Set 25 | muli
# Processing Record 18 of Set 25 | nizhniy kuranakh
# Processing Record 19 of Set 25 | mareeba
# Processing Record 20 of Set 25 | tunxi
# City not found. Skipping...
# Processing Record 21 of Set 25 | roebourne
# Processing Record 22 of Set 25 | luan
# Processing Record 23 of Set 25 | teyateyaneng
# Processing Record 24 of Set 25 | murgab
# Processing Record 25 of Set 25 | tateyama
# Processing Record 26 of Set 25 | sao felix do xingu
# Processing Record 27 of Set 25 | llangefni
# Processing Record 28 of Set 25 | pisco
# Processing Record 29 of Set 25 | klaksvik
# Processing Record 30 of Set 25 | matagami
# Processing Record 31 of Set 25 | khoy
# Processing Record 32 of Set 25 | tessalit
# Processing Record 33 of Set 25 | urubicha
# Processing Record 34 of Set 25 | jhabua
# Processing Record 35 of Set 25 | belmonte
# Processing Record 36 of Set 25 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 25 | jacareacanga
# Processing Record 38 of Set 25 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 25 | portel
# Processing Record 40 of Set 25 | fukue
# Processing Record 41 of Set 25 | moscow
# Processing Record 42 of Set 25 | sri aman
# Processing Record 43 of Set 25 | andenes
# Processing Record 44 of Set 25 | malysheva
# Processing Record 45 of Set 25 | paso de los toros
# Processing Record 46 of Set 25 | jinchang
# Processing Record 47 of Set 25 | sterling
# Processing Record 48 of Set 25 | axim
# Processing Record 49 of Set 25 | debre tabor
# Processing Record 50 of Set 25 | kapustin yar-1
# City not found. Skipping...
# Processing Record 1 of Set 26 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 26 | lashma
# Processing Record 3 of Set 26 | camopi
# Processing Record 4 of Set 26 | umm kaddadah
# Processing Record 5 of Set 26 | paramonga
# Processing Record 6 of Set 26 | havoysund
# Processing Record 7 of Set 26 | zhaotong
# Processing Record 8 of Set 26 | tran
# Processing Record 9 of Set 26 | taltal
# Processing Record 10 of Set 26 | vagur
# Processing Record 11 of Set 26 | ginir
# Processing Record 12 of Set 26 | jumla
# Processing Record 13 of Set 26 | teknaf
# Processing Record 14 of Set 26 | tulum
# Processing Record 15 of Set 26 | camacha
# Processing Record 16 of Set 26 | port macquarie
# Processing Record 17 of Set 26 | shebalino
# Processing Record 18 of Set 26 | ozumba
# City not found. Skipping...
# Processing Record 19 of Set 26 | taungdwingyi
# Processing Record 20 of Set 26 | tianpeng
# Processing Record 21 of Set 26 | emba
# Processing Record 22 of Set 26 | kenai
# Processing Record 23 of Set 26 | victor harbor
# Processing Record 24 of Set 26 | velykyy burluk
# Processing Record 25 of Set 26 | bokhan
# Processing Record 26 of Set 26 | kolosovka
# Processing Record 27 of Set 26 | babol
# Processing Record 28 of Set 26 | angoche
# Processing Record 29 of Set 26 | vladyslavivka
# Processing Record 30 of Set 26 | evensk
# Processing Record 31 of Set 26 | mackenzie
# Processing Record 32 of Set 26 | vermilion
# Processing Record 33 of Set 26 | rocha
# Processing Record 34 of Set 26 | aswan
# Processing Record 35 of Set 26 | lalsk
# Processing Record 36 of Set 26 | dunedin
# Processing Record 37 of Set 26 | tahe
# Processing Record 38 of Set 26 | koumac
# Processing Record 39 of Set 26 | nouadhibou
# Processing Record 40 of Set 26 | coahuayana
# Processing Record 41 of Set 26 | bathsheba
# Processing Record 42 of Set 26 | waddan
# Processing Record 43 of Set 26 | baracoa
# Processing Record 44 of Set 26 | hvolsvollur
# Processing Record 45 of Set 26 | new iberia
# Processing Record 46 of Set 26 | mlimba
# Processing Record 47 of Set 26 | zhuhai
# Processing Record 48 of Set 26 | hualmay
# Processing Record 49 of Set 26 | gastouri
# Processing Record 50 of Set 26 | bac lieu
# Processing Record 1 of Set 27 | cobija
# Processing Record 2 of Set 27 | cao bang
# Processing Record 3 of Set 27 | walvis bay
# Processing Record 4 of Set 27 | puerto maldonado
# Processing Record 5 of Set 27 | nedjo
# Processing Record 6 of Set 27 | port augusta
# Processing Record 7 of Set 27 | elko
# Processing Record 8 of Set 27 | kassala
# Processing Record 9 of Set 27 | miles city
# Processing Record 10 of Set 27 | visby
# Processing Record 11 of Set 27 | karpinsk
# Processing Record 12 of Set 27 | grindavik
# Processing Record 13 of Set 27 | saint-augustin
# Processing Record 14 of Set 27 | nipawin
# Processing Record 15 of Set 27 | ngunguru
# Processing Record 16 of Set 27 | geilo
# Processing Record 17 of Set 27 | voi
# Processing Record 18 of Set 27 | dingle
# Processing Record 19 of Set 27 | tombouctou
# Processing Record 20 of Set 27 | paralion astros
# City not found. Skipping...
# Processing Record 21 of Set 27 | oistins
# Processing Record 22 of Set 27 | tibu
# Processing Record 23 of Set 27 | pombas
# Processing Record 24 of Set 27 | shamgarh
# Processing Record 25 of Set 27 | santiago del estero
# Processing Record 26 of Set 27 | klyuchi
# Processing Record 27 of Set 27 | jhanjharpur
# Processing Record 28 of Set 27 | springbok
# Processing Record 29 of Set 27 | nizhniy tsasuchey
# Processing Record 30 of Set 27 | maceio
# Processing Record 31 of Set 27 | mangrol
# Processing Record 32 of Set 27 | soverato
# Processing Record 33 of Set 27 | biltine
# Processing Record 34 of Set 27 | vestmanna
# Processing Record 35 of Set 27 | gondanglegi
# Processing Record 36 of Set 27 | inta
# Processing Record 37 of Set 27 | mirik
# Processing Record 38 of Set 27 | upington
# Processing Record 39 of Set 27 | samarai
# Processing Record 40 of Set 27 | naze
# Processing Record 41 of Set 27 | thinadhoo
# Processing Record 42 of Set 27 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 43 of Set 27 | uppsala
# Processing Record 44 of Set 27 | the valley
# Processing Record 45 of Set 27 | dimapur
# Processing Record 46 of Set 27 | amapa
# Processing Record 47 of Set 27 | lata
# Processing Record 48 of Set 27 | bandarbeyla
# Processing Record 49 of Set 27 | yar-sale
# Processing Record 50 of Set 27 | avera
# Processing Record 1 of Set 28 | kokoda
# Processing Record 2 of Set 28 | kissidougou
# Processing Record 3 of Set 28 | kalavrita
# City not found. Skipping...
# Processing Record 4 of Set 28 | kajaani
# Processing Record 5 of Set 28 | auburn
# Processing Record 6 of Set 28 | pringsewu
# Processing Record 7 of Set 28 | pitimbu
# Processing Record 8 of Set 28 | ust-karsk
# Processing Record 9 of Set 28 | bafq
# Processing Record 10 of Set 28 | honningsvag
# Processing Record 11 of Set 28 | verkhoturye
# Processing Record 12 of Set 28 | ambon
# Processing Record 13 of Set 28 | yumen
# Processing Record 14 of Set 28 | hami
# Processing Record 15 of Set 28 | gogrial
# Processing Record 16 of Set 28 | san quintin
# Processing Record 17 of Set 28 | wanning
# Processing Record 18 of Set 28 | jablanica
# Processing Record 19 of Set 28 | bitung
# Processing Record 20 of Set 28 | nishihara
# Processing Record 21 of Set 28 | mascota
# Processing Record 22 of Set 28 | aitape
# Processing Record 23 of Set 28 | namatanai
# Processing Record 24 of Set 28 | champoton
# Processing Record 25 of Set 28 | azrow
# City not found. Skipping...
# Processing Record 26 of Set 28 | luebo
# Processing Record 27 of Set 28 | raduzhnyy
# Processing Record 28 of Set 28 | baoding
# Processing Record 29 of Set 28 | port blair
# Processing Record 30 of Set 28 | caetite
# Processing Record 31 of Set 28 | aksu
# Processing Record 32 of Set 28 | andros town
# Processing Record 33 of Set 28 | alice springs
# Processing Record 34 of Set 28 | tomatlan
# Processing Record 35 of Set 28 | okhotsk
# Processing Record 36 of Set 28 | itoman
# Processing Record 37 of Set 28 | alofi
# Processing Record 38 of Set 28 | brandfort
# Processing Record 39 of Set 28 | ushtobe
# Processing Record 40 of Set 28 | muroto
# Processing Record 41 of Set 28 | flin flon
# Processing Record 42 of Set 28 | ziro
# Processing Record 43 of Set 28 | houma
# Processing Record 44 of Set 28 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 28 | ayan
# Processing Record 46 of Set 28 | collecchio
# Processing Record 47 of Set 28 | krasnoarmeyskoye
# Processing Record 48 of Set 28 | pavilosta
# Processing Record 49 of Set 28 | barcelona
# Processing Record 50 of Set 28 | alekseyevka
# Processing Record 1 of Set 29 | christchurch
# Processing Record 2 of Set 29 | praia
# Processing Record 3 of Set 29 | oruro
# Processing Record 4 of Set 29 | moerai
# Processing Record 5 of Set 29 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 29 | wegorzewo
# Processing Record 7 of Set 29 | padilla
# Processing Record 8 of Set 29 | lumajang
# Processing Record 9 of Set 29 | la grande
# Processing Record 10 of Set 29 | galgani
# City not found. Skipping...
# Processing Record 11 of Set 29 | tual
# Processing Record 12 of Set 29 | dzilam gonzalez
# Processing Record 13 of Set 29 | prabumulih
# Processing Record 14 of Set 29 | afsin
# Processing Record 15 of Set 29 | dakar
# Processing Record 16 of Set 29 | mata
# Processing Record 17 of Set 29 | shingu
# Processing Record 18 of Set 29 | benoy
# Processing Record 19 of Set 29 | kangaba
# Processing Record 20 of Set 29 | siukh
# Processing Record 21 of Set 29 | ust-barguzin
# Processing Record 22 of Set 29 | urambo
# Processing Record 23 of Set 29 | tucupita
# Processing Record 24 of Set 29 | dauriya
# Processing Record 25 of Set 29 | altamira
# Processing Record 26 of Set 29 | oktyabrskoye
# Processing Record 27 of Set 29 | jasper
# Processing Record 28 of Set 29 | boyolangu
# Processing Record 29 of Set 29 | borinskoye
# Processing Record 30 of Set 29 | tezu
# Processing Record 31 of Set 29 | tuy hoa
# Processing Record 32 of Set 29 | leeds
# Processing Record 33 of Set 29 | sibolga
# Processing Record 34 of Set 29 | xiaoweizhai
# Processing Record 35 of Set 29 | kilosa
# Processing Record 36 of Set 29 | tucumcari
# Processing Record 37 of Set 29 | dukat
# Processing Record 38 of Set 29 | safaga
# Processing Record 39 of Set 29 | kaoma
# Processing Record 40 of Set 29 | omsukchan
# Processing Record 41 of Set 29 | barra patuca
# Processing Record 42 of Set 29 | llanes
# Processing Record 43 of Set 29 | helong
# Processing Record 44 of Set 29 | port victoria
# Processing Record 45 of Set 29 | saiha
# Processing Record 46 of Set 29 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 47 of Set 29 | dolbeau
# City not found. Skipping...
# Processing Record 48 of Set 29 | barbate
# Processing Record 49 of Set 29 | novoagansk
# Processing Record 50 of Set 29 | maryville
# Processing Record 1 of Set 30 | moose factory
# Processing Record 2 of Set 30 | laizhou
# Processing Record 3 of Set 30 | deh rawud
# City not found. Skipping...
# Processing Record 4 of Set 30 | satinka
# Processing Record 5 of Set 30 | soto la marina
# Processing Record 6 of Set 30 | semnan
# Processing Record 7 of Set 30 | port hedland
# Processing Record 8 of Set 30 | bulit
# Processing Record 9 of Set 30 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 30 | wakkanai
# Processing Record 11 of Set 30 | mecca
# Processing Record 12 of Set 30 | raga
# Processing Record 13 of Set 30 | kabelvag
# Processing Record 14 of Set 30 | mulege
# Processing Record 15 of Set 30 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 30 | asasa
# Processing Record 17 of Set 30 | poum
# Processing Record 18 of Set 30 | guerrero negro
# Processing Record 19 of Set 30 | pishin
# Processing Record 20 of Set 30 | guru har sahai
# Processing Record 21 of Set 30 | fengrun
# Processing Record 22 of Set 30 | nalut
# Processing Record 23 of Set 30 | guhagar
# Processing Record 24 of Set 30 | ko samui
# Processing Record 25 of Set 30 | ambulu
# Processing Record 26 of Set 30 | olafsvik
# Processing Record 27 of Set 30 | hohhot
# Processing Record 28 of Set 30 | calama
# Processing Record 29 of Set 30 | marshall
# Processing Record 30 of Set 30 | awjilah
# Processing Record 31 of Set 30 | buin
# Processing Record 32 of Set 30 | kazachinskoye
# Processing Record 33 of Set 30 | liwale
# Processing Record 34 of Set 30 | dongkan
# Processing Record 35 of Set 30 | parker
# Processing Record 36 of Set 30 | toora-khem
# Processing Record 37 of Set 30 | novo aripuana
# Processing Record 38 of Set 30 | biak
# Processing Record 39 of Set 30 | mmathubudukwane
# Processing Record 40 of Set 30 | redding
# Processing Record 41 of Set 30 | japura
# Processing Record 42 of Set 30 | korgen
# Processing Record 43 of Set 30 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 30 | finschhafen
# Processing Record 45 of Set 30 | mahajanga
# Processing Record 46 of Set 30 | mahon
# Processing Record 47 of Set 30 | shubarkuduk
# Processing Record 48 of Set 30 | whitehorse
# Processing Record 49 of Set 30 | duekoue
# Processing Record 50 of Set 30 | launceston
# Processing Record 1 of Set 31 | aksarka
# Processing Record 2 of Set 31 | marzuq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia -54.8000  -68.3000     35.26        69           0
# 1          Asau  46.4333   26.4000     64.40        89          76
# 2       Rikitea -23.1203 -134.9692     74.79        77          79
# 3       Fortuna  40.5982 -124.1573     59.41        71          90
# 4     Antsohihy -14.8796   47.9875     78.21        50          40
# ..          ...      ...       ...       ...       ...         ...
# 685  Whitehorse  60.7161 -135.0538     59.77        36          20
# 686     Duekoue   6.7472   -7.3496     69.22       100          76
# 687  Launceston -41.4500  147.1667     56.16        80          75
# 688     Aksarka  66.5606   67.7975     53.56        79          99
# 689      Marzuq  14.4000   46.4667     89.22        23          99
#
#      Wind Speed Country Current Description
# 0          5.75      AR           clear sky
# 1          5.64      RO       broken clouds
# 2         23.33      PF       broken clouds
# 3          1.99      US     overcast clouds
# 4         11.41      MG    scattered clouds
# ..          ...     ...                 ...
# 685        8.05      CA          few clouds
# 686        2.48      CI       broken clouds
# 687        1.01      AU       moderate rain
# 688       16.06      RU          light rain
# 689        1.92      YE     overcast clouds
#
# [690 rows x 9 columns]

# %%
new_col_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_col_order]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Ushuaia      AR -54.8000  -68.3000     35.26        69           0
# 1          Asau      RO  46.4333   26.4000     64.40        89          76
# 2       Rikitea      PF -23.1203 -134.9692     74.79        77          79
# 3       Fortuna      US  40.5982 -124.1573     59.41        71          90
# 4     Antsohihy      MG -14.8796   47.9875     78.21        50          40
# ..          ...     ...      ...       ...       ...       ...         ...
# 685  Whitehorse      CA  60.7161 -135.0538     59.77        36          20
# 686     Duekoue      CI   6.7472   -7.3496     69.22       100          76
# 687  Launceston      AU -41.4500  147.1667     56.16        80          75
# 688     Aksarka      RU  66.5606   67.7975     53.56        79          99
# 689      Marzuq      YE  14.4000   46.4667     89.22        23          99
#
#      Wind Speed Current Description
# 0          5.75           clear sky
# 1          5.64       broken clouds
# 2         23.33       broken clouds
# 3          1.99     overcast clouds
# 4         11.41    scattered clouds
# ..          ...                 ...
# 685        8.05          few clouds
# 686        2.48       broken clouds
# 687        1.01       moderate rain
# 688       16.06          light rain
# 689        1.92     overcast clouds
#
# [690 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
